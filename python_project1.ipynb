# %%
import pandas as pd

# %%
water_df=pd.read_csv('1_gecco2018_water_quality.csv')

# %%
water_df.head()
# Out:
#    Unnamed: 0                 Time   Tp    Cl    pH  Redox   Leit  Trueb  \
# 0           1  2016-08-03 11:49:00  6.5  0.17  8.36  749.0  211.0  0.011
# 1           2  2016-08-03 11:50:00  6.5  0.17  8.36  749.0  211.0  0.011
# 2           3  2016-08-03 11:51:00  6.5  0.17  8.35  749.0  211.0  0.011
# 3           4  2016-08-03 11:52:00  6.5  0.17  8.35  749.0  211.0  0.011
# 4           5  2016-08-03 11:53:00  6.5  0.17  8.35  749.0  211.0  0.011
#
#     Cl_2      Fm   Fm_2  EVENT
# 0  0.118  1677.0  695.0  False
# 1  0.118  1561.0  696.0  False
# 2  0.117  1581.0  696.0  False
# 3  0.118  1579.0  693.0  False
# 4  0.118  1567.0  689.0  False

# %%
water_df.dtypes
# Out:
# Unnamed: 0      int64
# Time           object
# Tp            float64
# Cl            float64
# pH            float64
# Redox         float64
# Leit          float64
# Trueb         float64
# Cl_2          float64
# Fm            float64
# Fm_2          float64
# EVENT            bool
# dtype: object

# %%
water_df.isnull().sum()
# Out:
# Unnamed: 0       0
# Time             0
# Tp            1044
# Cl            1045
# pH            1044
# Redox         1044
# Leit          1044
# Trueb         1044
# Cl_2          1044
# Fm            1044
# Fm_2          1044
# EVENT            0
# dtype: int64

# %%
water_df.dropna(inplace=True)
water_df.isnull().sum()
# Out:
# Unnamed: 0    0
# Time          0
# Tp            0
# Cl            0
# pH            0
# Redox         0
# Leit          0
# Trueb         0
# Cl_2          0
# Fm            0
# Fm_2          0
# EVENT         0
# dtype: int64

# %%
water_df.columns
# Out:
# Index(['Unnamed: 0', 'Time', 'Tp', 'Cl', 'pH', 'Redox', 'Leit', 'Trueb',
#        'Cl_2', 'Fm', 'Fm_2', 'EVENT'],
#       dtype='object')

# %%
water_df.columns=['index', 'Time', 'Tp', 'Cl', 'pH', 'Redox', 'Leit', 'Trueb',
       'Cl_2', 'Fm', 'Fm_2', 'EVENT']

# %%
water_df.columns
# Out:
# Index(['index', 'Time', 'Tp', 'Cl', 'pH', 'Redox', 'Leit', 'Trueb', 'Cl_2',
#        'Fm', 'Fm_2', 'EVENT'],
#       dtype='object')

# %%
water_df.drop(columns='index',inplace=True)

# %%
water_df.columns
# Out:
# Index(['Time', 'Tp', 'Cl', 'pH', 'Redox', 'Leit', 'Trueb', 'Cl_2', 'Fm',
#        'Fm_2', 'EVENT'],
#       dtype='object')

# %%
water_df.shape
# Out:
# (138521, 11)

# %%
water_df['date']=pd.to_datetime(water_df['Time'])

# %%
water_df['month']= water_df['date'].dt.month

# %%
water_df=water_df[water_df['month']!=11]

# %%
water_df['EVENT'].shape[0]
# Out:
# 127906

# %%
water_df['EVENT'].sum()
# Out:
# np.int64(1649)

# %%
(water_df['EVENT'].sum()/water_df['EVENT'].shape[0])*100
# Out:
# np.float64(1.289228026832205)

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
#1.How does water temperature affect other chemical properties?

# sns.heatmap(water_df.select_dtypes(include='number').corr(),annot=True);

# %%
#Are there any seasonal or time-based trends in water quality?

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
water_df.head()
# Out:
#                   Time   Tp    Cl    pH  Redox   Leit  Trueb   Cl_2      Fm  \
# 0  2016-08-03 11:49:00  6.5  0.17  8.36  749.0  211.0  0.011  0.118  1677.0
# 1  2016-08-03 11:50:00  6.5  0.17  8.36  749.0  211.0  0.011  0.118  1561.0
# 2  2016-08-03 11:51:00  6.5  0.17  8.35  749.0  211.0  0.011  0.117  1581.0
# 3  2016-08-03 11:52:00  6.5  0.17  8.35  749.0  211.0  0.011  0.118  1579.0
# 4  2016-08-03 11:53:00  6.5  0.17  8.35  749.0  211.0  0.011  0.118  1567.0
#
#     Fm_2  EVENT                date  month
# 0  695.0  False 2016-08-03 11:49:00      8
# 1  696.0  False 2016-08-03 11:50:00      8
# 2  696.0  False 2016-08-03 11:51:00      8
# 3  693.0  False 2016-08-03 11:52:00      8
# 4  689.0  False 2016-08-03 11:53:00      8

# %%
water_df.head()
# Out:
#                   Time   Tp    Cl    pH  Redox   Leit  Trueb   Cl_2      Fm  \
# 0  2016-08-03 11:49:00  6.5  0.17  8.36  749.0  211.0  0.011  0.118  1677.0
# 1  2016-08-03 11:50:00  6.5  0.17  8.36  749.0  211.0  0.011  0.118  1561.0
# 2  2016-08-03 11:51:00  6.5  0.17  8.35  749.0  211.0  0.011  0.117  1581.0
# 3  2016-08-03 11:52:00  6.5  0.17  8.35  749.0  211.0  0.011  0.118  1579.0
# 4  2016-08-03 11:53:00  6.5  0.17  8.35  749.0  211.0  0.011  0.118  1567.0
#
#     Fm_2  EVENT                date  month
# 0  695.0  False 2016-08-03 11:49:00      8
# 1  696.0  False 2016-08-03 11:50:00      8
# 2  696.0  False 2016-08-03 11:51:00      8
# 3  693.0  False 2016-08-03 11:52:00      8
# 4  689.0  False 2016-08-03 11:53:00      8

# %%
cl_2_df=water_df.groupby('month')[['Cl','Cl_2']].mean()
cl_2_df.head()
# Out:
#              Cl      Cl_2
# month
# 8      0.165194  0.110155
# 9      0.166041  0.106922
# 10     0.165427  0.102099

# %%
cl_2_df.reset_index(inplace = True)

# %%
cl_2_df.dtypes
# Out:
# month      int32
# Cl       float64
# Cl_2     float64
# dtype: object

# %%
abnormality_df=water_df[water_df['EVENT']==True]
abnormality_df
# Out:
#                       Time   Tp    Cl        pH       Redox   Leit     Trueb  \
# 16265  2016-08-14 18:54:00  6.9  0.17  8.567335  727.280805  211.0  0.028395
# 16266  2016-08-14 18:55:00  6.9  0.17  8.567335  727.280805  211.0  0.029395
# 16267  2016-08-14 18:56:00  6.9  0.17  8.567335  727.280805  211.0  0.028395
# 16268  2016-08-14 18:57:00  6.9  0.17  8.567335  727.280805  211.0  0.028395
# 16269  2016-08-14 18:58:00  6.9  0.17  8.567335  727.280805  211.0  0.028395
# ...                    ...  ...   ...       ...         ...    ...       ...
# 97356  2016-10-10 02:25:00  9.2  0.17  8.771052  756.000000  214.0  0.015000
# 97357  2016-10-10 02:26:00  9.1  0.17  8.789846  755.000000  217.0  0.015000
# 97358  2016-10-10 02:27:00  9.2  0.16  8.818640  756.000000  217.0  0.015000
# 97359  2016-10-10 02:28:00  9.2  0.16  8.837434  756.000000  214.0  0.015000
# 97360  2016-10-10 02:29:00  9.2  0.16  8.846228  756.000000  217.0  0.015000
#
# ...

# %%
abnormality_df.groupby('month')[['EVENT']].count()
# Out:
#        EVENT
# month
# 8        165
# 9       1310
# 10       174

# %%
import matplotlib.pyplot as plt

abnormality_df.groupby('month')[['EVENT']].count().rename(index={8:'Aug', 9:'Sep', 10:'Oct', 11:'Nov'}).plot(
    kind='line',
    figsize=(10, 5),
    legend=False,
   # title="Numder Of Event By Month",
     xlabel="",
    ylabel="Event Numbers");

# %%
cl_df.reset_index(inplace = True)

# %%
cl_df.head()
# Out:
#    index  month        Cl      Cl_2
# 0      0      8  0.167161  0.115699
# 1      1      9  0.156005  0.090668
# 2      2     10  0.167011  0.104741

# %%
abnormality_df.groupby('month')[['Leit','Trueb','Tp','Cl','Cl_2','pH','Redox']].mean()
# Out:
#              Leit     Trueb        Tp        Cl      Cl_2        pH  \
# month
# 8      209.624242  0.028066  7.009091  0.167161  0.115699  8.506705
# 9      206.746370  0.022056  8.286718  0.156005  0.090668  8.137314
# 10     214.988506  0.015747  9.052299  0.167011  0.104741  8.627079
#
#             Redox
# month
# 8      729.351831
# 9      702.881271
# 10     756.080460

# %%
abnormality_df[abnormality_df["month"].isin([8, 9, 10])].groupby("month")[["Fm", "Fm_2"]].mean().rename(index={8: "Aug", 9: "Sep", 10: "Oct"}).plot(kind="line", xlabel="", ylabel="Average Water Flowrates", figsize=(10, 5));

# %%
abnormality_df[abnormality_df["month"].isin([8, 9, 10])].groupby("month")[["Cl", "Cl_2"]].mean().rename(index={8: "Aug", 9: "Sep", 10: "Oct"}).plot(kind="line",  xlabel="", ylabel="Average Chlorine Dioxide", figsize=(10, 5));
plt.savefig('avg_dio.jpg', transparent=True)

# %%
abnormality_df[abnormality_df["month"].isin([8, 9, 10])].groupby("month")[["Redox"]].mean().rename(index={8: "Aug", 9: "Sep", 10: "Oct"}).plot(kind="line", xlabel="", ylabel="Average Redox", figsize=(10, 5),legend=False);

# %%
abnormality_df[abnormality_df["month"].isin([8, 9, 10])].groupby("month")[["pH"]].mean().rename(index={8: "Aug", 9: "Sep", 10: "Oct"}).plot(kind="line", xlabel="", ylabel="Average pH Value", figsize=(10, 5),legend=False);

# %%
color_list=['r','b', 'k']
abnormality_df[abnormality_df["month"].isin([8, 9, 10])].groupby("month")[["pH"]].mean().rename(index={8: "Aug", 9: "Sep", 10: "Oct"})#.sort_values("pH", ascending=True).reset_index()#.plot(x='month', y='pH', kind="barh", color=['re', 'g', 'b'], title="Average pH By Month", xlabel="Average pH", ylabel="", figsize=(10, 5), legend=False);
# Out:
#              pH
# month
# Aug    8.506705
# Sep    8.137314
# Oct    8.627079

# %%
sns.heatmap(abnormality_df.select_dtypes(include='number').corr(),annot=True);

# %%
# colors = ['skyblue'] * len(abnormality_df)  # Default color for all bars
# highlight_index = abnormality_df[abnormality_df['month'] == 10].index[0]
# highlight_index

# %%
# colors = ['skyblue'] * len(abnormality_df)  # Default color for all bars
# highlight_index = abnormality_df[abnormality_df['month'] == 10].index[0]
# colors[highlight_index] = 'red'  # Set specific color for bar 'C'
# # Create the bar chart with custom colors

# #color_list=['orange','blue', 'blue']
# abnormality_df[abnormality_df["month"].isin([8, 9, 10])].groupby("month")[["pH"]].mean().rename(index={8: "Aug", 9: "Sep", 10: "Oct"}).sort_values("pH", ascending=True).plot(kind="barh", color=colors, title="Average pH By Month", xlabel="Average pH", ylabel="", figsize=(10, 5));

# %%
# sns.heatmap(abnormality_df.select_dtypes(include='number').corr(),annot=True);

# %%
# plt.figure(figsize=(12, 6))
# plt.plot(cl_df['month'], cl_df['Cl'], marker='o', color='blue', linestyle='-', linewidth=2, label='Cl (Sensor 1)')
# plt.plot(cl_df['month'], cl_df['Cl_2'], marker='s', color='green', linestyle='--', linewidth=2, label='CL_2 (Sensor 2)')

# plt.title("Chlorine Dioxide Levels Over Time")
# plt.xlabel("Month")
# plt.ylabel("Concentration (mg/L)")
# plt.xticks([8, 9, 10])
# plt.legend()
# #plt.grid(True)
# plt.tight_layout()
# plt.show()

# %%
# sns.heatmap(abnormality_df.select_dtypes(include='number').corr(),annot=True)

# %%
# abnormality_df.groupby('month')[['Tp']].mean()

# %%
# water_df.groupby('month')[['Tp']].mean()

# %%
# water_df.groupby('month')[['Leit','Trueb','Tp','Cl','Cl_2','pH','Redox']].mean()

# %%
# water_df.groupby('month')[['Leit','Trueb','Tp','Cl','Cl_2','pH','Redox']].median()

# %%
# abnormality_df.groupby('month')[['Leit','Trueb','Tp','Cl','Cl_2','pH','Redox']].mean()

# %%
# abnormality_df[abnormality_df["month"].isin([8, 9, 10])].groupby("month")[["Trueb", "pH"]].mean().plot(kind="line",xticks=([8, 9, 10]),
#     title="Monthly Averaged",
#     xlabel="Month",
#     ylabel="Sensor",
#     figsize=(12, 6));

# %%
# abnormality_df[abnormality_df["month"].isin([8, 9, 10])].groupby("month")[["pH","Tp"]].mean().plot(kind="line",xticks=([8, 9, 10]),
#     title="Monthly Averaged",
#     xlabel="Month",
#     ylabel="Sensor",
#     figsize=(12, 6));

# %%
# abnormality_df.groupby('month')['Trueb'].mean().plot(kind='line', xlim=(8,11),xticks=([8, 9, 10]))

# %%
# water_df[water_df["month"].isin([8, 9, 10])].groupby("month")[["Fm", "Fm_2"]].mean().plot(kind="line",xticks=([8, 9, 10]),
#     title="Monthly Averaged Water Flowrates",
#     xlabel="Month",
#     ylabel="Sensor Reading",
#     figsize=(12, 6));

# %%
# abnormality_df[abnormality_df["month"].isin([8, 9, 10])].groupby("month")[["Fm", "Fm_2"]].mean().plot(kind="line",xticks=([8, 9, 10]),
#     title="Monthly Averaged Water Flowrates",
#     xlabel="Month",
#     ylabel="Sensor Reading",
#     figsize=(12, 6));

# %%
# abnormality_df[abnormality_df["month"].isin([8, 9, 10])].groupby("month")[["Cl", "Cl_2"]].mean().plot(kind="line",xticks=([8, 9, 10]),
#     title="Monthly Averaged Water Flowrates",
#     xlabel="Month",
#     ylabel="Sensor Reading",
#     figsize=(12, 6));

# %%
# abnormality_df[abnormality_df["month"].isin([8, 9, 10])].groupby("month")[["Redox"]].mean().plot(kind="line",xticks=([8, 9, 10]),
#     title="Monthly Averaged Water Flowrates",
#     xlabel="Month",
#     ylabel="Sensor Reading",
#     figsize=(12, 6));

# %%
# abnormality_df[abnormality_df["month"].isin([8, 9, 10])].groupby("month")[["Leit"]].mean().plot(kind="line",xticks=([8, 9, 10]),
#     title="Monthly Averaged Water Flowrates",
#     xlabel="Month",
#     ylabel="Sensor Reading",
#     figsize=(12, 6));

# %%
# abnormality_df[abnormality_df["month"].isin([8, 9, 10])].groupby("month")[["pH"]].mean().plot(kind="line",xticks=([8, 9, 10]),
#     title="Monthly Averaged",
#     xlabel="Month",
#     ylabel="Sensor",
#     figsize=(12, 6));
